# %%
import pandas as pd

# %%
# making Series(1D) of data for future prediction by list
name=['wert','met']
salary=[14000,30000]
pd.Series(salary,name)
# Out:
# wert    14000
# met     30000
# dtype: int64

# %%
pd.Series(salary,index=name)
# Out:
# wert    14000
# met     30000
# dtype: int64

# %%
#Series by dictionary
dicts={
    'wert':14000,
    'met':30000
}
record=pd.Series(dicts, name='record')
record
# Out:
# wert    14000
# met     30000
# Name: record, dtype: int64

# %%
# to find the size of series
record.size
# Out:
# 2

# %%
# finding the unique number in a series or not
record.is_unique
# Out:
# True

# %%
# to read the real dataset
sub=pd.read_csv('/stepo/python/subs.csv',squeeze=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_8216\1367108597.py:2: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   sub=pd.read_csv('/stepo/python/subs.csv',squeeze=True)

# %%
# squeeze help to transform dataframe into Series
type(sub)
sub
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
# to read two Series or two column
virat=pd.read_csv('/stepo/python/kohli_ipl.csv',index_col='match_no',squeeze=True)
virat
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_15672\2957681764.py:2: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   virat=pd.read_csv('/stepo/python/kohli_ipl.csv',index_col='match_no',squeeze=True)
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
# Out:
#      match_no  runs
# 0           1     1
# 1           2    23
# 2           3    13
# 3           4    12
# 4           5     1
# ..        ...   ...
# 210       211     0
# 211       212    20
# 212       213    73
# 213       214    25
# 214       215     7
#
# [215 rows x 2 columns]

# %%
movies=pd.read_csv('/stepo/python/bollywood.csv',index_col='movie',squeeze=True)
movies
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_15672\3509388840.py:1: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   movies=pd.read_csv('/stepo/python/bollywood.csv',index_col='movie',squeeze=True)
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %%
movies.head(2)
# Out:
# movie
# Uri: The Surgical Strike    Vicky Kaushal
# Battalion 609                 Vicky Ahuja
# Name: lead, dtype: object

# %%
movies.tail(2)
# Out:
# movie
# Company (film)            Ajay Devgn
# Awara Paagal Deewana    Akshay Kumar
# Name: lead, dtype: object

# %%
# To get random data from dataset
movies.sample(3)
# Out:
# movie
# Tom Dick and Harry (2006 film)       Rakesh Bedi
# Naam Shabana                       Taapsee Pannu
# Talaash: The Answer Lies Within       Aamir Khan
# Name: lead, dtype: object

# %%
# counting the number of movies done lead hero
movies.value_counts()
# Out:
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Diganth              1
# Parveen Kaur         1
# Seema Azmi           1
# Akanksha Puri        1
# Edwin Fernandes      1
# Name: lead, Length: 566, dtype: int64

# %%
#sorting the data and finding the max run of virat in the data
virat.sort_values(ascending=False).head(1).values[0]
# Out:
# 113

# %%
# sorting the index in dataset
movies.sort_index().tail(2)
# Out:
# movie
# Zokkomon                 Darsheel Safary
# Zor Lagaa Ke...Haiya!      Meghan Jadhav
# Name: lead, dtype: object

# %%
movies.count()
# Out:
# 1500

# %%
# counting the total number of run
virat.sum()
# Out:
# 6634

# %%
virat.mean()
# Out:
# 30.855813953488372

# %%
virat.median()
# Out:
# 24.0

# %%
virat.std()
# Out:
# 26.22980132830278

# %%
print(virat.max())
print(virat.min())
# Out:
# 113
# 0

# %%
# provide all statical calculation
virat.describe()
# Out:
# count    215.000000
# mean      30.855814
# std       26.229801
# min        0.000000
# 25%        9.000000
# 50%       24.000000
# 75%       48.000000
# max      113.000000
# Name: runs, dtype: float64

# %%
virat.product()
# Out:
# 0

# %%
#indexing the dataset
print(virat)
virat[214]
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64
# 25

# %%
virat[:6:2]
# Out:
# match_no
# 1     1
# 3    13
# 5     1
# Name: runs, dtype: int64

# %%
#fancy indexing get multiple desire data with index
virat[[1,8,215]]
# Out:
# match_no
# 1      1
# 8      0
# 215    7
# Name: runs, dtype: int64

# %%
# chnaging the dataset with the help of index value
virat[1]=100
virat
# Out:
# match_no
# 1      100
# 2       23
# 3       13
# 4       12
# 5        1
#       ...
# 211      0
# 212     20
# 213     73
# 214     25
# 215      7
# Name: runs, Length: 215, dtype: int64

# %%
# can change multiple place data with slicing
virat[2:4]=[100,100]
virat
# Out:
# match_no
# 1      100
# 2       23
# 3      100
# 4      100
# 5        1
#       ...
# 211      0
# 212     20
# 213     73
# 214     25
# 215      7
# Name: runs, Length: 215, dtype: int64

# %%
# can chage specific data using fancy index
virat[[1,2,3,4]]=[1,2,3,4]
virat
# Out:
# match_no
# 1       1
# 2       2
# 3       3
# 4       4
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
print(len(virat))
# Out:
# 215

# %%
print(type(virat))
# Out:
# <class 'pandas.core.series.Series'>

# %%
# dir show the all method that object can use as functinality
print(dir(virat))
# Out:
# ['T', '_AXIS_LEN', '_AXIS_ORDERS', '_AXIS_TO_AXIS_NUMBER', '_HANDLED_TYPES', '__abs__', '__add__', '__and__', '__annotations__', '__array__', '__array_priority__', '__array_ufunc__', '__array_wrap__', '__bool__', '__class__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__divmod__', '__doc__', '__eq__', '__finalize__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__imod__', '__imul__', '__init__', '__init_subclass__', '__int__', '__invert__', '__ior__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__long__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rmatmul__',
# ...

# %%
# converting to different data type
list(virat)
# Out:
# [1,
#  2,
#  3,
#  4,
#  1,
#  9,
#  34,
#  0,
#  21,
#  3,
#  10,
#  38,
#  3,
#  11,
#  50,
#  2,
#  22,
#  19,
#  16,
#  15,
#  20,
#  38,
#  19,
#  24,
#  7,
#  2,
#  16,
#  17,
#  24,
#  38,
#  34,
#  42,
#  13,
#  58,
#  3,
#  14,
#  37,
#  9,
#  23,
#  12,
#  71,
#  35,
#  30,
#  56,
#  67,
#  27,
#  27,
#  39,
#  15,
#  11,
#  31,
#  70,
#  8,
#  35,
#  8,
#  6,
#  57,
#  22,
#  16,
#  4,
#  16,
#  18,
#  45,
#  9,
#  36,
#  9,
#  3,
#  73,
#  42,
#  24,
#  51,
#  35,
#  58,
#  65,
#  1,
#  11,
#  1,
#  32,
#  25,
#  57,
#  93,
#  99,
#  17,
#  14,
#  56,
#  49,
#  0,
#  31,
#  21,
#  4,
#  0,
#  35,
#  0,
#  4,
#  10,
#  27,
#  67,
#  38,
#  73,
#  13,
#  41,
#  18,
#  51,
#  62,
#  35,
#  1,
#  34,
#  48,
#  32,
#  82,
#  19,
#  44,
#  1,
#  12,
#  12,
#  75,
#  79,
#  33,
#  80,
#  100,
#  14,
#  52,
#  108,
#  20,
#  7,
#  109,
#  75,
#  113,
#  54,
#  0,
#  54,
#  62,
#  28,
#  64,
#  0,
#  10,
#  55,
#  20,
#  6,
#  5,
#  58,
#  31,
#  21,
#  57,
#  92,
#  30,
#  18,
# ...

# %%
# searching through the index data by default in work with index 
print(movies)
'Why Cheat India' in movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object
# True

# %%
# for search in value
'Akshay Kumar' in movies.values
# Out:
# True

# %%
# loop in dataset
virat.shape
for i in virat:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 1
# 9
# 34
# 0
# 21
# 3
# 10
# 38
# 3
# 11
# 50
# 2
# 22
# 19
# 16
# 15
# 20
# 38
# 19
# 24
# 7
# 2
# 16
# 17
# 24
# 38
# 34
# 42
# 13
# 58
# 3
# 14
# 37
# 9
# 23
# 12
# 71
# 35
# 30
# 56
# 67
# 27
# 27
# 39
# 15
# 11
# 31
# 70
# 8
# 35
# 8
# 6
# 57
# 22
# 16
# 4
# 16
# 18
# 45
# 9
# 36
# 9
# 3
# 73
# 42
# 24
# 51
# 35
# 58
# 65
# 1
# 11
# 1
# 32
# 25
# 57
# 93
# 99
# 17
# 14
# 56
# 49
# 0
# 31
# 21
# 4
# 0
# 35
# 0
# 4
# 10
# 27
# 67
# 38
# 73
# 13
# 41
# 18
# 51
# 62
# 35
# 1
# 34
# 48
# 32
# 82
# 19
# 44
# 1
# 12
# 12
# 75
# 79
# 33
# 80
# 100
# 14
# 52
# 108
# 20
# 7
# 109
# 75
# 113
# 54
# 0
# 54
# 62
# 28
# 64
# 0
# 10
# 55
# 20
# 6
# 5
# 58
# 31
# 21
# 57
# 92
# 30
# 18
# 68
# 32
# 8
# 39
# 70
# 48
# 12
# 4
# 6
# 46
# 3
# 23
# 84
# 41
# 67
# 8
# 100
# 9
# 13
# 23
# 25
# 16
# 18
# 9
# 7
# 29
# 1
# 72
# 43
# 43
# 90
# 48
# 14
# 33
# 50
# 8
# 6
# 33
# 33
# 5
# 72
# 8
# 12
# 35
# 5
# 25
# 5
# 4
# 25
# 51
# 53
# 39
# 41
# 12
# 5
# 48
# 1
# 12
# 0
# 0
# 9
# 58
# 30
# ...

# %%
# using condition change into the desire dataset
virat[virat>=50]
# Out:
# match_no
# 15      50
# 34      58
# 41      71
# 44      56
# 45      67
# 52      70
# 57      57
# 68      73
# 71      51
# 73      58
# 74      65
# 80      57
# 81      93
# 82      99
# 85      56
# 97      67
# 99      73
# 103     51
# 104     62
# 110     82
# 116     75
# 117     79
# 119     80
# 120    100
# 122     52
# 123    108
# 126    109
# 127     75
# 128    113
# 129     54
# 131     54
# 132     62
# 134     64
# 137     55
# 141     58
# 144     57
# 145     92
# 148     68
# 152     70
# 160     84
# 162     67
# 164    100
# 175     72
# 178     90
# 182     50
# 188     72
# 197     51
# 198     53
# 209     58
# 213     73
# Name: runs, dtype: int64

# %%
virat[virat>=70].size
# Out:
# 23

# %%
# for plotting the graph
virat.plot()
# Out:
# <AxesSubplot:xlabel='match_no'>

# %%
virat.head(20).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='match_no'>

# %%
virat.head(25).plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='runs'>

# %%
# size chnage of data
import sys
sys.getsizeof(virat)
# Out:
# 3456

# %%
# we can change the size of stored data
sys.getsizeof(virat.astype('int16'))
# Out:
# 2166

# %%
virat[virat.between(40,50)]
# Out:
# match_no
# 15     50
# 32     42
# 63     45
# 69     42
# 86     49
# 101    41
# 108    48
# 112    44
# 153    48
# 157    46
# 161    41
# 176    43
# 177    43
# 179    48
# 182    50
# 200    41
# 203    48
# Name: runs, dtype: int64

# %%
# drop the duplicate value
a=pd.Series([1,12,3,1,12,3,4])
a.drop_duplicates()
# Out:
# 0     1
# 1    12
# 2     3
# 6     4
# dtype: int64

# %%
a.duplicated().sum()
# Out:
# 3

# %%
import numpy as np
b=pd.Series([1,2,3,np.nan,np.nan])
b.isnull().sum()
# Out:
# 2

# %%
# handling the missing value\
b.dropna()
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# dtype: float64

# %%
b.fillna(8)
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    8.0
# 4    8.0
# dtype: float64

# %%
b.fillna(b.mean())
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    2.0
# 4    2.0
# dtype: float64

# %%
# searching the multiple desire data in the dataset
virat.isin([23,44,99]).sum()
# Out:
# 6

# %%
# making your own custom logic using apply
movies.apply(lambda x:x.split())
# Out:
# movie
# Uri: The Surgical Strike                   [Vicky, Kaushal]
# Battalion 609                                [Vicky, Ahuja]
# The Accidental Prime Minister (film)         [Anupam, Kher]
# Why Cheat India                            [Emraan, Hashmi]
# Evening Shadows                         [Mona, Ambegaonkar]
#                                                ...
# Hum Tumhare Hain Sanam                   [Shah, Rukh, Khan]
# Aankhen (2002 film)                     [Amitabh, Bachchan]
# Saathiya (film)                             [Vivek, Oberoi]
# Company (film)                                [Ajay, Devgn]
# Awara Paagal Deewana                        [Akshay, Kumar]
# Name: lead, Length: 1500, dtype: object

# %%
# Data Frame using list
import pandas as pd
student=[['w',60,1],['s',65,0],['q',80,1]]
pd.DataFrame(student,columns=['name','score','placed'])
# Out:
#   name  score  placed
# 0    w     60       1
# 1    s     65       0
# 2    q     80       1

# %%
#using dictanary
student={
    'name':['w','s','q'],
    'score':[60,65,80],
    'placed':[1,0,1]
}
pd.DataFrame(student)
# Out:
#   name  score  placed
# 0    w     60       1
# 1    s     65       0
# 2    q     80       1

# %%
movie=pd.read_csv('movies.csv')
movie
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movie.shape
# Out:
# (1629, 18)

# %%
movie.dtypes
# Out:
# title_x              object
# imdb_id              object
# poster_path          object
# wiki_link            object
# title_y              object
# original_title       object
# is_adult              int64
# year_of_release       int64
# runtime              object
# genres               object
# imdb_rating         float64
# imdb_votes            int64
# story                object
# summary              object
# tagline              object
# actors               object
# wins_nominations     object
# release_date         object
# dtype: object

# %%
# To show the column in the dataframe(dataset) 
movie.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')

# %%
# it convert dataset into 2D array
movie.values
# Out:
# array([['Uri: The Surgical Strike', 'tt8291224',
#         'https://upload.wikimedia.org/wikipedia/en/thumb/3/3b/URI_-_New_poster.jpg/220px-URI_-_New_poster.jpg',
#         ...,
#         'Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Gautam|Kirti Kulhari|Rajit Kapoor|Ivan Rodrigues|Manasi Parekh|Swaroop Sampat|Riva Arora|Yogesh Soman|Fareed Ahmed|Akashdeep Arora|Kallol Banerjee|',
#         '4 wins', '11 January 2019 (USA)'],
#        ['Battalion 609', 'tt9472208', nan, ...,
#         'Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elena Kazan|Vishwas Kini|Major Kishore|Jashn Kohli|Rammy C. Pandey|Manish Sharma|Sparsh Sharma|Farnaz Shetty|Vikas Shrivastav|Chandraprakash Thakur|Brajesh Tiwari|',
#         nan, '11 January 2019 (India)'],
#        ['The Accidental Prime Minister (film)', 'tt6986710',
#         'https://upload.wikimedia.org/wikipedia/en/thumb/a/a1/The_Accidental_Prime_Minister_film.jpg/220px-The_Accidental_Prime_Minister_film.jpg',
#         ...,
# ...

# %%
# it show the first row all values
movie.values[0]
# Out:
# array(['Uri: The Surgical Strike', 'tt8291224',
#        'https://upload.wikimedia.org/wikipedia/en/thumb/3/3b/URI_-_New_poster.jpg/220px-URI_-_New_poster.jpg',
#        'https://en.wikipedia.org/wiki/Uri:_The_Surgical_Strike',
#        'Uri: The Surgical Strike', 'Uri: The Surgical Strike', 0, 2019,
#        '138', 'Action|Drama|War', 8.4, 35112,
#        'Divided over five chapters  the film chronicles the events of the surgical strike conducted by the Indian military against suspected militants in Pakistan occupied Kashmir. It tells the story of the 11 tumultuous events over which the operation was carried out. Indian army special forces carry out a covert operation to avenge the killing of fellow army men at their base by a terrorist group.',
#        'Indian army special forces execute a covert operation  avenging the killing of fellow army men at their base by a terrorist group.',
#        nan,
# ...

# %%
# random row from the data using sample
movie.sample(3)
# Out:
#             title_x    imdb_id  \
# 475    Ragini MMS 2  tt2609218
# 1467  Pinjar (film)  tt0347779
# 551   The Shaukeens  tt3848888
#
#                                             poster_path  \
# 475   https://upload.wikimedia.org/wikipedia/en/thum...
# 1467                                                NaN
# 551   https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                         wiki_link        title_y  \
# 475    https://en.wikipedia.org/wiki/Ragini_MMS_2   Ragini MMS 2
# 1467  https://en.wikipedia.org/wiki/Pinjar_(film)         Pinjar
# 551   https://en.wikipedia.org/wiki/The_Shaukeens  The Shaukeens
#
#                     original_title  is_adult  year_of_release runtime  genres  \
# 475                   Ragini MMS 2         0             2014     119  Horror
# 1467  Pinjar: Beyond Boundaries...         0             2003     188   Drama
# 551                  The Shaukeens         0             2014     124  Comedy
#
# ...

# %%
# information about the dataset
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
# describe help to provide statistics overview of only numerical columns
movie.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
# duplicate show the same row is duplicate or not
movie.duplicated().sum()
# Out:
# 0

# %%
# To find the null values in the dataset
movie.isnull().sum()
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
# To change the columns name use rename
movie.rename(columns={'release_date':'date'}).head(1)
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
#
#                                                story  \
# 0  Divided over five chapters  the film chronicle...
#
#                                              summary tagline  \
# 0  Indian army special forces execute a covert op...     NaN
#
#                                               actors wins_nominations  \
# 0  Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...           4 wins
#
# ...

# %%
# to fetch the single columns
movie['title_x']
# Out:
# 0                   Uri: The Surgical Strike
# 1                              Battalion 609
# 2       The Accidental Prime Minister (film)
# 3                            Why Cheat India
# 4                            Evening Shadows
#                         ...
# 1624                   Tera Mera Saath Rahen
# 1625                    Yeh Zindagi Ka Safar
# 1626                         Sabse Bada Sukh
# 1627                                   Daaka
# 1628                                Humsafar
# Name: title_x, Length: 1629, dtype: object

# %%
# to fetch the multiple columns using fancy indexing
movie[['title_x','actors']]
# Out:
#                                    title_x  \
# 0                 Uri: The Surgical Strike
# 1                            Battalion 609
# 2     The Accidental Prime Minister (film)
# 3                          Why Cheat India
# 4                          Evening Shadows
# ...                                    ...
# 1624                 Tera Mera Saath Rahen
# 1625                  Yeh Zindagi Ka Safar
# 1626                       Sabse Bada Sukh
# 1627                                 Daaka
# 1628                              Humsafar
#
#                                                  actors
# 0     Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...
# 1     Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...
# 2     Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...
# 3     Emraan Hashmi|Shreya Dhanwanthary|Snighdadeep ...
# 4     Mona Ambegaonkar|Ananth Narayan Mahadevan|Deva...
# ...                                                 ...
# ...

# %%
# for accessing the row data
movie.iloc[1]
# Out:
# title_x                                                 Battalion 609
# imdb_id                                                     tt9472208
# poster_path                                                       NaN
# wiki_link                 https://en.wikipedia.org/wiki/Battalion_609
# title_y                                                 Battalion 609
# original_title                                          Battalion 609
# is_adult                                                            0
# year_of_release                                                  2019
# runtime                                                           131
# genres                                                            War
# imdb_rating                                                       4.1
# imdb_votes                                                         73
# story               The story revolves around a cricket match betw...
# ...

# %%
# for acessing multiple row data
movie.iloc[0:3]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
#
#                          title_y                 original_title  is_adult  \
# 0       Uri: The Surgical Strike       Uri: The Surgical Strike         0
# 1                  Battalion 609                  Battalion 609         0
# 2  The Accidental Prime Minister  The Accidental Prime Minister         0
#
# ...

# %%
movie.iloc[3:8:2]
# Out:
#            title_x    imdb_id  \
# 3  Why Cheat India  tt8108208
# 5      Soni (film)  tt6078866
# 7       Bombairiya  tt4971258
#
#                                          poster_path  \
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 5  https://upload.wikimedia.org/wikipedia/en/thum...
# 7  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                        wiki_link          title_y  \
# 3  https://en.wikipedia.org/wiki/Why_Cheat_India  Why Cheat India
# 5      https://en.wikipedia.org/wiki/Soni_(film)             Soni
# 7       https://en.wikipedia.org/wiki/Bombairiya       Bombairiya
#
#     original_title  is_adult  year_of_release runtime              genres  \
# 3  Why Cheat India         0             2019     121         Crime|Drama
# 5             Soni         0             2018      97               Drama
# 7       Bombairiya         0             2019     104  Comedy|Crime|Drama
#
# ...

# %%
# using fancy indexing
movie.iloc[[0,10,100]]
# Out:
#                       title_x    imdb_id  \
# 0    Uri: The Surgical Strike  tt8291224
# 10                     Amavas  tt8396186
# 100       October (2018 film)  tt7700730
#
#                                            poster_path  \
# 0    https://upload.wikimedia.org/wikipedia/en/thum...
# 10   https://upload.wikimedia.org/wikipedia/en/thum...
# 100  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                              wiki_link  \
# 0    https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 10                https://en.wikipedia.org/wiki/Amavas
# 100  https://en.wikipedia.org/wiki/October_(2018_film)
#
#                       title_y            original_title  is_adult  \
# 0    Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 10                     Amavas                    Amavas         0
# 100                   October                   October         0
#
#      year_of_release runtime            genres  imdb_rating  imdb_votes  \
# ...

# %%
# changing indexing and modifying the dataset
#movie.set_index('title_x',inplace=True)
movie
# Out:
#                                          imdb_id  \
# title_x
# Uri: The Surgical Strike               tt8291224
# Battalion 609                          tt9472208
# The Accidental Prime Minister (film)   tt6986710
# Why Cheat India                        tt8108208
# Evening Shadows                        tt6028796
# ...                                          ...
# Tera Mera Saath Rahen                  tt0301250
# Yeh Zindagi Ka Safar                   tt0298607
# Sabse Bada Sukh                        tt0069204
# Daaka                                 tt10833860
# Humsafar                               tt2403201
#
#                                                                             poster_path  \
# title_x
# Uri: The Surgical Strike              https://upload.wikimedia.org/wikipedia/en/thum...
# Battalion 609                                                                       NaN
# The Accidental Prime Minister (film)  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# using string index fetching row
movie.loc['Daaka']
# Out:
# imdb_id                                                    tt10833860
# poster_path         https://upload.wikimedia.org/wikipedia/en/thum...
# wiki_link                         https://en.wikipedia.org/wiki/Daaka
# title_y                                                         Daaka
# original_title                                                  Daaka
# is_adult                                                            0
# year_of_release                                                  2019
# runtime                                                           136
# genres                                                         Action
# imdb_rating                                                       7.4
# imdb_votes                                                         38
# story               Shinda tries robbing a bank so he can be wealt...
# summary             Shinda tries robbing a bank so he can be wealt...
# ...

# %%
# to fetch multiple row
movie.loc['Evening Shadows':'Daaka':2]
# Out:
#                                     imdb_id  \
# title_x
# Evening Shadows                   tt6028796
# Fraud Saiyaan                     tt5013008
# Manikarnika: The Queen of Jhansi  tt6903440
# Amavas                            tt8396186
# Hum Chaar                         tt9319812
# ...                                     ...
# Rahul (film)                      tt0277981
# Yeh Raaste Hain Pyaar Ke          tt0292740
# Yeh Teraa Ghar Yeh Meraa Ghar     tt0298606
# Tera Mera Saath Rahen             tt0301250
# Sabse Bada Sukh                   tt0069204
#
#                                                                         poster_path  \
# title_x
# Evening Shadows                                                                 NaN
# Fraud Saiyaan                     https://upload.wikimedia.org/wikipedia/en/thum...
# Manikarnika: The Queen of Jhansi  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# slicing both row and column
movie.iloc[0:4,0:3]
# Out:
#                                         imdb_id  \
# title_x
# Uri: The Surgical Strike              tt8291224
# Battalion 609                         tt9472208
# The Accidental Prime Minister (film)  tt6986710
# Why Cheat India                       tt8108208
#
#                                                                             poster_path  \
# title_x
# Uri: The Surgical Strike              https://upload.wikimedia.org/wikipedia/en/thum...
# Battalion 609                                                                       NaN
# The Accidental Prime Minister (film)  https://upload.wikimedia.org/wikipedia/en/thum...
# Why Cheat India                       https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                                                               wiki_link
# title_x
# Uri: The Surgical Strike              https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# ...

# %%
# action movies with rating higher than 7.5
movie.head(1)
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
#
#                                                story  \
# 0  Divided over five chapters  the film chronicle...
#
#                                              summary tagline  \
# 0  Indian army special forces execute a covert op...     NaN
#
#                                               actors wins_nominations  \
# 0  Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...           4 wins
#
# ...

# %%
condition1 = movie['genres'].str.split('|').apply(lambda x:'Action' in x)
condition2 = movie['imdb_rating'] > 7.5
movie[condition1 & condition2].shape[0]
# Out:
# 33

# %%
movie[(movie['genres']=='Action')].shape[0]
# Out:
# 15

# %%
import pandas as pd
movie=pd.read_csv('movies.csv')
movie
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# To sort the title_x with alphabetical order
movie.sort_values('title_x').tail()
# Out:
#                        title_x    imdb_id  \
# 778   Zindagi Na Milegi Dobara  tt1562872
# 670          Zindagi Tere Naam  tt2164702
# 756                   Zokkomon  tt1605790
# 939      Zor Lagaa Ke...Haiya!  tt1479857
# 1623                  Zubeidaa  tt0255713
#
#                                             poster_path  \
# 778   https://upload.wikimedia.org/wikipedia/en/thum...
# 670   https://upload.wikimedia.org/wikipedia/en/thum...
# 756   https://upload.wikimedia.org/wikipedia/en/thum...
# 939   https://upload.wikimedia.org/wikipedia/en/thum...
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link  \
# 778   https://en.wikipedia.org/wiki/Zindagi_Na_Mileg...
# 670     https://en.wikipedia.org/wiki/Zindagi_Tere_Naam
# 756              https://en.wikipedia.org/wiki/Zokkomon
# 939   https://en.wikipedia.org/wiki/Zor_Lagaa_Ke...H...
# 1623             https://en.wikipedia.org/wiki/Zubeidaa
#
# ...

# %%
# To sort the year wise as well as alphabetic title_x
movie.sort_values(['year_of_release','title_x'])
# Out:
#                                title_x     imdb_id  \
# 1575                       Aalavandhan   tt0294264
# 1576  Aamdani Atthanni Kharcha Rupaiya   tt0305173
# 1577                Aashiq (2001 film)   tt0273406
# 1579               Ajnabee (2001 film)   tt0278291
# 1578                   Aks (2001 film)   tt0289845
# ...                                ...         ...
# 64                         Ujda Chaman  tt11046300
# 0             Uri: The Surgical Strike   tt8291224
# 3                      Why Cheat India   tt8108208
# 60                  Yaaram (2019 film)  tt11007050
# 73                  Yeh Saali Aashiqui  tt10443846
#
#                                             poster_path  \
# 1575  https://upload.wikimedia.org/wikipedia/en/thum...
# 1576  https://upload.wikimedia.org/wikipedia/en/thum...
# 1577  https://upload.wikimedia.org/wikipedia/en/c/c6...
# 1579  https://upload.wikimedia.org/wikipedia/en/thum...
# 1578  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# To rank the series from dataframe
movie['imdb_votes'].rank(ascending=False)
# Out:
# 0         53.0
# 1       1434.0
# 2        345.0
# 3        624.0
# 4       1173.5
#          ...
# 1624    1175.5
# 1625    1335.5
# 1626    1594.5
# 1627    1529.5
# 1628     501.0
# Name: imdb_votes, Length: 1629, dtype: float64

# %%
# to set the index
movie
# Out:
#                                          imdb_id  \
# title_x
# Uri: The Surgical Strike               tt8291224
# Battalion 609                          tt9472208
# The Accidental Prime Minister (film)   tt6986710
# Why Cheat India                        tt8108208
# Evening Shadows                        tt6028796
# ...                                          ...
# Tera Mera Saath Rahen                  tt0301250
# Yeh Zindagi Ka Safar                   tt0298607
# Sabse Bada Sukh                        tt0069204
# Daaka                                 tt10833860
# Humsafar                               tt2403201
#
#                                                                             poster_path  \
# title_x
# Uri: The Surgical Strike              https://upload.wikimedia.org/wikipedia/en/thum...
# Battalion 609                                                                       NaN
# The Accidental Prime Minister (film)  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# to sort the index(alphabetically)
movie.sort_index()
# Out:
#                             imdb_id  \
# title_x
# 16 December (film)        tt0313844
# 1920 (film)               tt1301698
# 1920: London              tt5638500
# 1920: The Evil Returns    tt2222550
# 1971 (2007 film)          tt0983990
# ...                             ...
# Zindagi Na Milegi Dobara  tt1562872
# Zindagi Tere Naam         tt2164702
# Zokkomon                  tt1605790
# Zor Lagaa Ke...Haiya!     tt1479857
# Zubeidaa                  tt0255713
#
#                                                                 poster_path  \
# title_x
# 16 December (film)        https://upload.wikimedia.org/wikipedia/en/thum...
# 1920 (film)               https://upload.wikimedia.org/wikipedia/en/thum...
# 1920: London              https://upload.wikimedia.org/wikipedia/en/thum...
# 1920: The Evil Returns    https://upload.wikimedia.org/wikipedia/en/e/e7...
# 1971 (2007 film)          https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# we can change multiple columns name using rename
movie.rename(columns={'imdb_id':'imdb'})
# Out:
#                                             imdb  \
# title_x
# Uri: The Surgical Strike               tt8291224
# Battalion 609                          tt9472208
# The Accidental Prime Minister (film)   tt6986710
# Why Cheat India                        tt8108208
# Evening Shadows                        tt6028796
# ...                                          ...
# Tera Mera Saath Rahen                  tt0301250
# Yeh Zindagi Ka Safar                   tt0298607
# Sabse Bada Sukh                        tt0069204
# Daaka                                 tt10833860
# Humsafar                               tt2403201
#
#                                                                             poster_path  \
# title_x
# Uri: The Surgical Strike              https://upload.wikimedia.org/wikipedia/en/thum...
# Battalion 609                                                                       NaN
# The Accidental Prime Minister (film)  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# we can also change multiple index usimg rename
movie.rename(index={'Uri: The Surgical Strike':'uri'})
# Out:
#                                          imdb_id  \
# title_x
# uri                                    tt8291224
# Battalion 609                          tt9472208
# The Accidental Prime Minister (film)   tt6986710
# Why Cheat India                        tt8108208
# Evening Shadows                        tt6028796
# ...                                          ...
# Tera Mera Saath Rahen                  tt0301250
# Yeh Zindagi Ka Safar                   tt0298607
# Sabse Bada Sukh                        tt0069204
# Daaka                                 tt10833860
# Humsafar                               tt2403201
#
#                                                                             poster_path  \
# title_x
# uri                                   https://upload.wikimedia.org/wikipedia/en/thum...
# Battalion 609                                                                       NaN
# The Accidental Prime Minister (film)  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# to check the columns has nan value or not
movie['release_date'].hasnans
# Out:
# True

# %%
movie['release_date'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1624    False
# 1625    False
# 1626     True
# 1627    False
# 1628    False
# Name: release_date, Length: 1629, dtype: bool

# %%
# dropna help to delete row data if any consist of nan value(null)
print(movie.shape)
movie.dropna().shape
# Out:
# (1629, 18)
# (298, 18)

# %%
movie.sample(10)
# Out:
#                  title_x    imdb_id  \
# 1302       Tango Charlie  tt0444913
# 1090   Khoya Khoya Chand  tt0995823
# 582         Bloody Isshq  tt2404187
# 1461  Market (2003 film)  tt0381408
# 771          Bheja Fry 2  tt1939654
# 1081   Gauri: The Unborn  tt0982875
# 227       The Final Exit  tt7340684
# 1057         Apna Asmaan  tt1073097
# 1345   Hatya (2004 film)  tt0432536
# 103        Nanu Ki Jaanu  tt7412738
#
#                                             poster_path  \
# 1302  https://upload.wikimedia.org/wikipedia/en/thum...
# 1090  https://upload.wikimedia.org/wikipedia/en/thum...
# 582   https://upload.wikimedia.org/wikipedia/en/thum...
# 1461  https://upload.wikimedia.org/wikipedia/en/thum...
# 771   https://upload.wikimedia.org/wikipedia/en/thum...
# 1081  https://upload.wikimedia.org/wikipedia/en/thum...
# 227   https://upload.wikimedia.org/wikipedia/en/thum...
# 1057  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# basically, we can remove null value related to associated columns only
#(release_date nan value is delete only)
movie.dropna(subset='release_date').shape
# Out:
# (1522, 18)

# %%
# we can do multiple columns too if release_date OR story contains nan then delete whole row
movie.dropna(subset=['release_date','story']).shape
# Out:
# (1514, 18)

# %%
movie['wins_nominations'].fillna(0)
# Out:
# 0                       4 wins
# 1                            0
# 2                            0
# 3                            0
# 4       17 wins & 1 nomination
#                  ...
# 1624                         0
# 1625                         0
# 1626                         0
# 1627                         0
# 1628                         0
# Name: wins_nominations, Length: 1629, dtype: object

# %%
data=pd.DataFrame({
    'name':['maw','man','nan','man'],
    'marks':[60,70,50,70]
})
data
# Out:
#   name  marks
# 0  maw     60
# 1  man     70
# 2  nan     50
# 3  man     70

# %%
# helps to find the duplicated row
data.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# dtype: bool

# %%
# we can easily delete duplicated data in dataset as shown in example
data.drop_duplicates(keep='first')
# Out:
#   name  marks
# 0  maw     60
# 1  man     70
# 2  nan     50

# %%
# you can delete the columns and row of the dataset
movie.drop(columns=['poster_path','wiki_link'])
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                             title_y                 original_title  is_adult  \
# 0          Uri: The Surgical Strike       Uri: The Surgical Strike         0
# 1                     Battalion 609                  Battalion 609         0
# ...

# %%
# index too
movie.drop(index=[0,1628])
# Out:
#                                    title_x     imdb_id  \
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# 5                              Soni (film)   tt6078866
# ...                                    ...         ...
# 1623                              Zubeidaa   tt0255713
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
#
#                                             poster_path  \
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                   NaN
# ...

# %%
# using apply function in dataframe
print(data)
def averaged(row):
    ave=row['marks']
    return ave/2
data.apply(averaged,axis=1)
# Out:
#   name  marks
# 0  maw     60
# 1  man     70
# 2  nan     50
# 3  man     70
# 0    30.0
# 1    35.0
# 2    25.0
# 3    35.0
# dtype: float64
